# %%
import torch
from torch import nn

# %%
x = torch.rand(2, 3, 7, 7)
x
# Out:
# tensor([[[[0.3051, 0.1998, 0.6780, 0.1155, 0.8459, 0.5379, 0.1397],
#           [0.3567, 0.7545, 0.6626, 0.2634, 0.8889, 0.5617, 0.2515],
#           [0.6869, 0.2174, 0.5320, 0.9062, 0.5771, 0.2508, 0.0827],
#           [0.1783, 0.9176, 0.7079, 0.0294, 0.2739, 0.7964, 0.0020],
#           [0.9356, 0.3288, 0.7065, 0.1153, 0.5035, 0.8472, 0.0167],
#           [0.3508, 0.5956, 0.2128, 0.6857, 0.8795, 0.9305, 0.6941],
#           [0.2107, 0.1087, 0.8655, 0.5711, 0.2320, 0.2544, 0.4864]],
#
#          [[0.0610, 0.7458, 0.3776, 0.4047, 0.5745, 0.0156, 0.4418],
#           [0.8953, 0.0371, 0.5726, 0.3547, 0.1402, 0.9191, 0.0472],
#           [0.4430, 0.9169, 0.1230, 0.1122, 0.5735, 0.5815, 0.3562],
#           [0.8094, 0.0585, 0.6419, 0.4093, 0.6739, 0.9623, 0.6137],
#           [0.2889, 0.8721, 0.1066, 0.7885, 0.1735, 0.7626, 0.5934],
#           [0.5861, 0.4504, 0.9371, 0.1984, 0.8081, 0.8502, 0.2124],
#           [0.6573, 0.7322, 0.9618, 0.4072, 0.2986, 0.0074, 0.6082]],
#
#          [[0.8999, 0.5857, 0.8022, 0.4776, 0.2889, 0.3936, 0.7623],
#           [0.0911, 0.6633, 0.8458, 0.8061, 0.0757, 0.7336, 0.2411],
#           [0.9332, 0.2800, 0.0412, 0.0266, 0.4870, 0.5864, 0.9342],
#           [0.7072, 0.0116, 0.7885, 0.8507, 0.6846, 0.7994, 0.4242],
#           [0.3851, 0.1334, 0.4139, 0.6654, 0.5175, 0.3068, 0.7139],
#           [0.9681, 0.6205, 0.0043, 0.9868, 0.4602, 0.5827, 0.9488],
#           [0.2189, 0.7227, 0.2401, 0.2948, 0.7723, 0.6177, 0.1161]]],
#
#
#         [[[0.1833, 0.3863, 0.0345, 0.4814, 0.7294, 0.1523, 0.6751],
#           [0.7286, 0.6293, 0.0208, 0.9759, 0.7835, 0.5151, 0.8620],
#           [0.1850, 0.2980, 0.2201, 0.7274, 0.3958, 0.4055, 0.0910],
#           [0.4804, 0.5347, 0.4421, 0.9955, 0.5023, 0.4375, 0.9171],
#           [0.1181, 0.4778, 0.9469, 0.6167, 0.2291, 0.2873, 0.2656],
#           [0.4133, 0.3290, 0.7416, 0.1925, 0.0700, 0.4171, 0.7946],
#           [0.9675, 0.7832, 0.9349, 0.9394, 0.0405, 0.9192, 0.5814]],
#
#          [[0.3935, 0.3426, 0.0448, 0.1785, 0.6859, 0.1576, 0.1140],
#           [0.0763, 0.5679, 0.3155, 0.0984, 0.0045, 0.9653, 0.1021],
#           [0.4382, 0.4092, 0.4166, 0.6739, 0.4198, 0.1215, 0.4300],
#           [0.4722, 0.1040, 0.1955, 0.9592, 0.6628, 0.7050, 0.7615],
#           [0.5774, 0.7152, 0.7309, 0.4270, 0.8270, 0.7563, 0.0285],
#           [0.8698, 0.7270, 0.8543, 0.2187, 0.8804, 0.1230, 0.6249],
#           [0.3547, 0.1934, 0.5992, 0.2980, 0.0999, 0.8777, 0.0279]],
#
#          [[0.0622, 0.0647, 0.9864, 0.6354, 0.2455, 0.8109, 0.0411],
#           [0.2433, 0.9846, 0.8422, 0.9905, 0.7638, 0.4824, 0.3989],
#           [0.6096, 0.9014, 0.1621, 0.2319, 0.3661, 0.7406, 0.5349],
#           [0.1038, 0.8749, 0.2469, 0.8870, 0.9684, 0.7684, 0.7087],
#           [0.0117, 0.4243, 0.8254, 0.9438, 0.5288, 0.3859, 0.2381],
#           [0.4470, 0.6892, 0.1697, 0.6918, 0.8614, 0.6356, 0.6749],
#           [0.3572, 0.6032, 0.4324, 0.0496, 0.1614, 0.5905, 0.9198]]]])

# %%
net = nn.BatchNorm2d(3)
net(x).shape
# Out:
# torch.Size([2, 3, 7, 7])

# %%
def batch_norm(x):
    return torch.mean(x, dim=(0, 2, 3), keepdim=True)

# %%
batch_norm(x)
# Out:
# tensor([[[[0.4909]],
#
#          [[0.4673]],
#
#          [[0.5328]]]])
