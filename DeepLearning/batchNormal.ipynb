# %%
import torch
from torch import nn

# %%
x = torch.rand(2, 3, 7, 7)
x
# Out:
# tensor([[[[0.4764, 0.0504, 0.7874, 0.1683, 0.1120, 0.2809, 0.2889],
#           [0.0320, 0.7801, 0.2913, 0.7696, 0.2605, 0.4990, 0.9167],
#           [0.1520, 0.4499, 0.9267, 0.0387, 0.9508, 0.1982, 0.6739],
#           [0.8158, 0.3334, 0.8484, 0.8883, 0.5444, 0.8855, 0.6050],
#           [0.3443, 0.2385, 0.0485, 0.6999, 0.0212, 0.8993, 0.6715],
#           [0.0702, 0.6298, 0.8748, 0.2947, 0.9502, 0.5438, 0.8151],
#           [0.6446, 0.0428, 0.0350, 0.9689, 0.9743, 0.4539, 0.9758]],
#
#          [[0.0377, 0.3141, 0.4786, 0.4525, 0.9196, 0.9702, 0.3949],
#           [0.8493, 0.4637, 0.1901, 0.7723, 0.5018, 0.1516, 0.1683],
#           [0.5185, 0.0743, 0.4697, 0.2269, 0.9616, 0.7387, 0.6071],
#           [0.2064, 0.7138, 0.3084, 0.5194, 0.2224, 0.2313, 0.2055],
#           [0.2448, 0.1551, 0.4794, 0.9906, 0.3071, 0.7309, 0.8624],
#           [0.0406, 0.2214, 0.5066, 0.9492, 0.2144, 0.5769, 0.0349],
#           [0.6067, 0.2769, 0.2508, 0.3789, 0.7842, 0.6639, 0.1508]],
#
#          [[0.4161, 0.8515, 0.9589, 0.8679, 0.7430, 0.2505, 0.9432],
#           [0.3702, 0.1122, 0.5475, 0.6982, 0.5204, 0.3253, 0.3700],
#           [0.1546, 0.5735, 0.4197, 0.4763, 0.4300, 0.7460, 0.8269],
#           [0.4418, 0.7304, 0.1943, 0.7787, 0.9529, 0.1282, 0.0242],
#           [0.7419, 0.2513, 0.5577, 0.8235, 0.1560, 0.2363, 0.8861],
#           [0.7727, 0.6524, 0.2254, 0.5166, 0.4027, 0.6872, 0.3832],
#           [0.4645, 0.6728, 0.8055, 0.9265, 0.8752, 0.7919, 0.3406]]],
#
#
#         [[[0.9378, 0.9877, 0.0053, 0.0217, 0.6489, 0.1846, 0.9987],
#           [0.8594, 0.2890, 0.9292, 0.3890, 0.9353, 0.8888, 0.4889],
#           [0.0916, 0.7885, 0.7413, 0.9989, 0.5846, 0.2281, 0.7556],
#           [0.6140, 0.0367, 0.4351, 0.5758, 0.8232, 0.7314, 0.7021],
#           [0.7860, 0.6483, 0.3549, 0.2866, 0.3866, 0.7354, 0.0680],
#           [0.8342, 0.4142, 0.2611, 0.3076, 0.7446, 0.5129, 0.4249],
#           [0.5473, 0.6118, 0.3874, 0.1166, 0.4851, 0.1937, 0.3437]],
#
#          [[0.6906, 0.0920, 0.4373, 0.5323, 0.5878, 0.6426, 0.1602],
#           [0.7416, 0.8824, 0.2096, 0.5733, 0.0367, 0.6234, 0.4574],
#           [0.6626, 0.7225, 0.6458, 0.8013, 0.8445, 0.9414, 0.5633],
#           [0.8648, 0.4506, 0.6153, 0.1582, 0.1601, 0.4652, 0.0310],
#           [0.4376, 0.9695, 0.6501, 0.8345, 0.5270, 0.2815, 0.5698],
#           [0.3242, 0.3909, 0.6683, 0.7849, 0.1437, 0.9466, 0.5632],
#           [0.7379, 0.6553, 0.5595, 0.3401, 0.3031, 0.7916, 0.1407]],
#
#          [[0.8652, 0.8771, 0.8600, 0.9543, 0.3349, 0.3458, 0.0290],
#           [0.6896, 0.5995, 0.7988, 0.4549, 0.8805, 0.2327, 0.3109],
#           [0.9133, 0.6371, 0.9458, 0.2335, 0.1486, 0.3620, 0.9492],
#           [0.4295, 0.3808, 0.3242, 0.1125, 0.3840, 0.2916, 0.7878],
#           [0.2657, 0.4811, 0.2900, 0.4081, 0.7480, 0.7316, 0.1726],
#           [0.4676, 0.4268, 0.3309, 0.0914, 0.7408, 0.1936, 0.8801],
#           [0.5432, 0.4394, 0.7487, 0.3570, 0.7608, 0.4664, 0.3839]]]])

# %%
net = nn.BatchNorm2d(3)
net(x).shape
# Out:
# torch.Size([2, 3, 7, 7])

# %%
def batch_norm(x):
    return torch.mean(x, dim=(0, 2, 3), keepdim=True)

# %%
batch_norm(x).shape
# Out:
# torch.Size([1, 3, 1, 1])
